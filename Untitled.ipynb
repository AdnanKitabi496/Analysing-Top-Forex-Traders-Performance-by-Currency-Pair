# %%
import pandas as pd

# %%
df= pd.read_csv('column.csv')

# %%
df
# Out:
#    TICKET  LOGIN  SYMBOL  DIGITS                  CMD  VOLUME  OPEN_TIME  \
# 0     NaN      0       6       1  2006-06-02 21:00:21  0.0000     0.0000
# 1  GBPUSD      4       1      10  2006-06-05 15:39:04  1.8805     1.8804
# 2  GBPUSD      4       1      20  2006-06-05 15:53:46  1.8799     0.0000
# 3  EURUSD      4       0      10  2006-06-05 16:13:20  1.2929     0.0000
# 4  GBPUSD      4       1      20  2006-06-05 17:00:27  1.8779     1.8889
# 5  GBPUSD      4       1      20  2006-06-05 20:06:15  1.8791     1.8895
# 6  GBPUSD      4       1      20  2006-06-06 09:58:05  1.8760     0.0000
# 7  GBPUSD      4       0      20  2006-06-06 12:36:32  1.8718     0.0000
# 8  GBPUSD      4       0      20  2006-06-06 13:17:49  1.8704     0.0000
# 9  GBPUSD      4       1      40  2006-06-06 18:04:50  1.8593     0.0000
#
#    OPEN_PRICE                   SL                   TP  ...  PROFIT  \
# 0      0.0000  2006-06-02 21:00:21  1970-01-01 00:00:00  ...     0.0
# ...
